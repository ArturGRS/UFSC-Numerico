# %% [markdown]
# ### Tarefa
#
# 1. Crie um polinômio; Partindo de um conjunto de 5 pontos
# 2. Utilize o Matplotlib para gerar o gráfico do item 1
# 3. Utilize o Scipy para calcular a devidada e dps a raiz através do metodo de newton!

# %%
import matplotlib.pyplot as plt
import scipy

Pontos = [(2,-4),(3,-2),(5,-1),(9,+2),(12,4)]

# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt

x = [0, 1, 2]
y = [1, 3, 2]

P1_coeff = [1,-1.5,.5]

# get the polynomial function
P1 = poly.Polynomial(P1_coeff)

x_new = np.arange(-1.0, 3.1, 0.1)

fig = plt.figure(figsize = (10,8))
plt.plot(x_new, P1(x_new), 'b', label = 'P1')

plt.plot(x, np.ones(len(x)), 'ko', x, np.zeros(len(x)), 'ko')
plt.title('Lagrange Basis Polynomials')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()
